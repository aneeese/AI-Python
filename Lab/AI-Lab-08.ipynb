# %%
#Solved

def iterative_deepening_dfs(start, target):
    depth = 1
    bottom_reached = False
    while not bottom_reached:
        result, bottom_reached = iterative_deepening_defs_rec(start, target, 0, depth)
        if result is not None:
            return result
        depth *= 2
        print("Increasing depth to ", str(depth))
        
    return None


def iterative_deepening_defs_rec(node, target, current_depth, max_depth):
    print("Visiting Node ", str(node["value"]))
    if node["value"] == target:
        print("Found the node we are looking for")
        return node, True
    
    if current_depth == max_depth:
        print("Current maximum depth reached, returning .....")
        if (len(node["children"]) > 0):
            return None, False
        else:
            return None, True
        
    bottom_reached = True
    for i in range(len(node["children"])):
        result, bottom_reached_rec = iterative_deepening_defs_rec(node["children"][i], target, current_depth + 1, max_depth)
        
        if result is not None:
            return result, True
        bottom_reached = bottom_reached and bottom_reached_rec
    
    return None, bottom_reached


start = {
    "value":0, "children":[
        {"value":1, "children":[
            {"value":3, "children":[]},
            {"value":4, "children":[]}
            
        ]},
       { "value":2, "children":[
            {"value":5, "children":[]},
            {"value":6, "children":[]}
        ]
}
    ]
}
   
print(iterative_deepening_dfs(start, 6)["value"])
# Out:
# Visiting Node  0
# Visiting Node  1
# Current maximum depth reached, returniing .....
# Visiting Node  2
# Current maximum depth reached, returniing .....
# Increasing depth to  2
# Visiting Node  0
# Visiting Node  1
# Visiting Node  3
# Current maximum depth reached, returniing .....
# Visiting Node  4
# Current maximum depth reached, returniing .....
# Visiting Node  2
# Visiting Node  5
# Current maximum depth reached, returniing .....
# Visiting Node  6
# Found the node we are looking for
# 6

# %%
# Graded

def iterative_deepening_dfs(start, target):
    depth = 1
    bottom_reached = False
    while not bottom_reached:
        result, bottom_reached = iterative_deepening_defs_rec(start, target, 0, depth)
        if result is not None:
            return result
        depth *= 2
        print("Increasing depth to ", str(depth))
        
    return None


def iterative_deepening_defs_rec(node, target, current_depth, max_depth):
    print("Visiting Node ", str(node["value"]))
    if node["value"] == target:
        print("Found the node we are looking for")
        return node, True
    
    if current_depth == max_depth:
        print("Current maximum depth reached, returning .....")
        if (len(node["children"]) > 0):
            return None, False
        else:
            return None, True
        
    bottom_reached = True
    for i in range(len(node["children"])):
        result, bottom_reached_rec = iterative_deepening_defs_rec(node["children"][i], target, current_depth + 1, max_depth)
        
        if result is not None:
            return result, True
        bottom_reached = bottom_reached and bottom_reached_rec
    
    return None, bottom_reached

start = {
    "value": "A", "children": [
        {
            "value": "B", "children": [
                {
                    "value": "C", "children": [
                        {
                            "value": "D", "children": [
                                {
                                    "value": "E", "children": [
                                        {
                                            "value": "F", "children": [
                                                {
                                                    "value": "G", "children": [
                                                        {
                                                            "value": "H", "children": [
                                                                {
                                                                    "value": "I", "children": [
                                                                        {
                                                                            "value": "J", "children": [
                                                                                {
                                                                                    "value": "K", "children": [
                                                                                        {
                                                                                            "value": "L", "children": [
                                                                                                {
                                                                                                    "value": "M", "children": [
                                                                                                        {
                                                                                                            "value": "N", "children": []
                                                                                                        }
                                                                                                    ]
                                                                                                }
                                                                                            ]
                                                                                        }
                                                                                    ]
                                                                                }
                                                                            ]
                                                                        }
                                                                    ]
                                                                }
                                                            ]
                                                        }
                                                    ]
                                                }
                                            ]
                                        }
                                    ]
                                },
                                {
                                    "value": "Y", "children": [
                                        {
                                            "value": "X", "children": [
                                                {
                                                    "value": "Z", "children": []
                                                },
                                                {
                                                    "value": "W", "children": [
                                                        {
                                                            "value": "V", "children": [
                                                                {
                                                                    "value": "U", "children": [
                                                                        {
                                                                            "value": "S", "children": [
                                                                                {
                                                                                    "value": "T", "children": []
                                                                                },
                                                                                {
                                                                                    "value": "R", "children": [
                                                                                        {
                                                                                            "value": "Q", "children": [
                                                                                                {
                                                                                                    "value": "O", "children": [
                                                                                                        {
                                                                                                            "value": "P", "children": []
                                                                                                        }
                                                                                                    ]
                                                                                                }
                                                                                            ]
                                                                                        }
                                                                                    ]
                                                                                }
                                                                            ]
                                                                        }
                                                                    ]
                                                                }
                                                            ]
                                                        }
                                                    ]
                                                }
                                            ]
                                        }
                                    ]
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ]
}
   
   
print(iterative_deepening_dfs(start, "P")["value"])
# Out:
# Visiting Node  A
# Visiting Node  B
# Current maximum depth reached, returning .....
# Increasing depth to  2
# Visiting Node  A
# Visiting Node  B
# Visiting Node  C
# Current maximum depth reached, returning .....
# Increasing depth to  4
# Visiting Node  A
# Visiting Node  B
# Visiting Node  C
# Visiting Node  D
# Visiting Node  E
# Current maximum depth reached, returning .....
# Visiting Node  Y
# Current maximum depth reached, returning .....
# Increasing depth to  8
# Visiting Node  A
# Visiting Node  B
# Visiting Node  C
# Visiting Node  D
# Visiting Node  E
# Visiting Node  F
# Visiting Node  G
# Visiting Node  H
# Visiting Node  I
# Current maximum depth reached, returning .....
# Visiting Node  Y
# Visiting Node  X
# Visiting Node  Z
# Visiting Node  W
# Visiting Node  V
# Visiting Node  U
# Current maximum depth reached, returning .....
# Increasing depth to  16
# Visiting Node  A
# Visiting Node  B
# Visiting Node  C
# Visiting Node  D
# Visiting Node  E
# ...
